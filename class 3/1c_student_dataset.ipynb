# %%
import pandas as pd
df=pd.read_csv("data.csv",sep=";")
display(df)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#using Pearson correlation
plt.figure(figsize=(8,4))
cor_matrix=df.corr()
print(cor_matrix)
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.264006
# Application order                                    -0.125854
# Course                                                0.046365
# Daytime/evening attendance\t                         -0.274939
# Previous qualification                                0.062529
# Previous qualification (grade)                       -0.022406
# Nacionality                                          -0.008843
# Mother's qualification                                0.193163
# Father's qualification                                0.130353
# Mother's occupation                                   0.034994
# Father's occupation                                   0.031609
# Admission grade                                      -0.004771
# Displaced                                            -0.234886
# ...

# %%
plt.figure(figsize=(36,36))
cor_matrix=df.corr()
sns.heatmap(cor_matrix,annot=True,cmap=plt.cm.Reds)
plt.show
# Out:
# C:\Users\22i270\AppData\Local\Temp\ipykernel_15452\1182596734.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_matrix=df.corr()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
d=df.iloc[:,21:31]
print(df)
plt.figure(figsize=(11,11))
cor_matrix=d.corr()
sns.heatmap(cor_matrix,annot=True,cmap=plt.cm.Reds)
plt.show
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
print(cor_matrix.columns)
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
#Correlation with output variable


try:
    cor_target = abs(cor_matrix['Curricular units 1st sem (credited)'])
    print(cor_target)
    relevant_features = cor_target[cor_target > 0.5]  
    print(relevant_features)
except KeyError as e:
    print(f"Error accessing column: {e}")
# Out:
# Marital status                                    0.061209
# Application mode                                  0.247426
# Application order                                 0.133354
# Course                                            0.096335
# Daytime/evening attendance\t                      0.127466
# Previous qualification                            0.166025
# Previous qualification (grade)                    0.008872
# Nacionality                                       0.000370
# Mother's qualification                            0.046855
# Father's qualification                            0.040054
# Mother's occupation                               0.008353
# Father's occupation                               0.003012
# Admission grade                                   0.040829
# Displaced                                         0.097268
# Educational special needs                         0.024411
# Debtor                                            0.034053
# ...
